# %%
import trig_functions as trig

# %%
pi = trig.pi

print(f'sin(0) should be 0: we get {trig.sin(0)}')
print(f'sin(pi/2) should be 1: we get {trig.sin(pi/2)}')
print(f'cos(0) should be 1: we get {trig.cos(0)}')
print(f'cos(pi/0) should be 0: we get {trig.cos(pi/2)}')
print(f'tan(0) should be 0: we get {trig.tan(0)}')
print(f'tan(pi/2) should be infinity: we get {trig.tan(pi/2)}')
print(f'cos(pi/4) should be 1: we get {trig.tan(pi/4)}')
# Out:
# sin(0) should be 0: we get 0.0
# sin(pi/2) should be 1: we get 0.99999999874975
# cos(0) should be 1: we get 1.0
# cos(pi/0) should be 0: we get -5.000500034976676e-05
# tan(0) should be 0: we get 0.0
# tan(pi/2) should be infinity: we get -19998.000035098776
# cos(pi/4) should be 1: we get 1.0000500062506623
